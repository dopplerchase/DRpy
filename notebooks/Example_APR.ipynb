# %% [markdown]
# <a href="https://colab.research.google.com/github/dopplerchase/DRpy/blob/master/notebooks/Example_APR.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # This Notebook is to show off the functionality of the APR class
#
# The APR class is for loading in APR2/APR3 files into an xarray dataset. The example here is using a file from olympex, but the file has been thinned inorder to meet github's filesize requirement.
#
# Note: GCPEX files require hdf4 readers, which I have not tested here. I think the package I have is this one: https://github.com/fhs/pyhdf

# %%
#clone repository
# !git clone https://github.com/dopplerchase/DRpy.git
    
import os
#cd into folder
os.chdir('./DRpy/')
#install 
# !python setup.py install

#cd into notebooks 
os.chdir('./notebooks/')

# %%
import drpy
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
filename = '../example_file/olympex_apr3_20151203_150904_R2_KUsKAsWs.h5'
apr = drpy.core.APR()
apr.read(filename=filename,campaign='olympex')
# Out:
# No vv, using hh
# /data/keeling/a/randyjc2/anaconda3/lib/python3.7/site-packages/drpy/core/gpmdpr.py:899: RuntimeWarning: invalid value encountered in less_equal
#   radar_n3 = np.ma.masked_where(radar3 <= -99,radar3)

# %%
plt.pcolormesh(apr.xrds.time3d[:,12,:],apr.xrds.alt3d[:,12,:],apr.xrds.Ku[:,12,:],cmap=drpy.graph.cmaps.HomeyerRainbow,vmin=0,vmax=40)
plt.colorbar()
# Out:
# /data/keeling/a/randyjc2/anaconda3/lib/python3.7/site-packages/pandas/plotting/_converter.py:129: FutureWarning: Using an implicitly registered datetime converter for a matplotlib plotting method. The converter was registered by pandas on import. Future versions of pandas will require you to explicitly register matplotlib converters.
#
# To register the converters:
# 	>>> from pandas.plotting import register_matplotlib_converters
# 	>>> register_matplotlib_converters()
#   warnings.warn(msg, FutureWarning)

# %%
#deletes data near the Ku-band minimum sensitivty 
apr.cloudtopmask()

# %%
plt.pcolormesh(apr.xrds.time3d[:,12,:],apr.xrds.alt3d[:,12,:],apr.xrds.Ku[:,12,:],cmap=drpy.graph.cmaps.HomeyerRainbow,vmin=0,vmax=40)
plt.colorbar()
